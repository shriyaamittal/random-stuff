# %%
import matplotlib.pylab as plt
# %matplotlib inline

font = {'family':'Helvetica'}
plt.rc('font', **font)
plt.rcParams.update({'font.size':12})
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rc('savefig', dpi=900)
plt.rc('axes',labelsize=12,labelweight='bold')
plt.rc('legend',fontsize=12)
from pylab import rcParams

# %%
import random
import numpy as np

# %%
x1=[50,100,150,200,250,300]
y1=random.sample(np.arange(1.5,6,0.02),len(x1))

# %%
y1
# Out:
# [1.9200000000000004,
#  3.640000000000002,
#  2.460000000000001,
#  2.560000000000001,
#  4.160000000000002,
#  3.1000000000000014]

# %%
x2=[100,150,200,250]
y2=random.sample(np.arange(1,6,0.02),len(x2))

# %%
y2
# Out:
# [3.8200000000000025, 2.9600000000000017, 3.9200000000000026, 5.580000000000004]

# %%
plt.plot(x1,y1,color='b')
plt.plot(x1,y1,'o',color='b',alpha=0.75)
plt.xlim(40,310)
plt.ylim(0,6)
# Out:
# (0, 6)

# %%
plt.plot(x1,y1,color='b')
plt.plot(x1,y1,'o',color='b',alpha=0.75)

plt.plot(x2,y2,color='r')
plt.plot(x2,y2,'o',color='r',alpha=0.75)

plt.xlim(40,310)
plt.ylim(1,6)
# Out:
# (1, 6)

# %%
x3=[100,150,200,250,300]
y3=[1.98,5.43,4.67,4.12,4.8]

plt.plot(x3,y3,color='g')
plt.plot(x3,y3,'o',color='g',alpha=0.75)

plt.xlim(40,310)
plt.ylim(1,6)
# Out:
# (1, 6)

# %%
5*0.9
# Out:
# 4.5
